# %%
import numpy as np 
import matplotlib.pyplot as plt 
import pandas as pd 
import os

print("Imports Success")
# Out:
# Imports Success

# %%
import os 
for dir,_,filenames in os.walk('../data/raw/for-tcn/'):
    print(dir)
    for file in filenames:
        print(os.path.join(dir,file))
# Out:
# ../data/raw/for-tcn/
# ../data/raw/for-tcn/pesticides.csv
# ../data/raw/for-tcn/rainfall.csv
# ../data/raw/for-tcn/temp.csv
# ../data/raw/for-tcn/yield.csv
# ../data/raw/for-tcn/yield_df.csv

# %%
PATH = "../data/raw/for-tcn/"

# %%
df = pd.read_csv(PATH+"/pesticides.csv")
print(df.head())
# Out:
#            Domain     Area Element                Item  Year  \
# 0  Pesticides Use  Albania     Use  Pesticides (total)  1990
# 1  Pesticides Use  Albania     Use  Pesticides (total)  1991
# 2  Pesticides Use  Albania     Use  Pesticides (total)  1992
# 3  Pesticides Use  Albania     Use  Pesticides (total)  1993
# 4  Pesticides Use  Albania     Use  Pesticides (total)  1994
#
#                            Unit  Value
# 0  tonnes of active ingredients  121.0
# 1  tonnes of active ingredients  121.0
# 2  tonnes of active ingredients  121.0
# 3  tonnes of active ingredients  121.0
# 4  tonnes of active ingredients  201.0

# %%
df.columns
# Out:
# Index(['Domain', 'Area', 'Element', 'Item', 'Year', 'Unit', 'Value'], dtype='object')

# %%
print("Unique Countries : ",df['Area'].unique().size)
# Out:
# Unique Countries :  168
